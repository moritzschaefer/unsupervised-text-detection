# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
img = cv2.imread('../data/test_images/111-1152_IMG.jpg')
prediction = np.load('../data/text_prediction_image.npy')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-085fa7764796> in <module>()
#       1 img = cv2.imread('../data/test_images/111-1152_IMG.jpg')
# ----> 2 prediction = np.load('../data/text_prediction_image.npy')
#
# /usr/lib/python3.6/site-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     360     own_fid = False
#     361     if isinstance(file, basestring):
# --> 362         fid = open(file, "rb")
#     363         own_fid = True
#     364     else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/text_prediction_image.npy'

# %%
plt.imshow(img)
plt.show()

# %%
plt.imshow(prediction, cmap = plt.get_cmap('gray'))

# %%
text_probability_image = np.zeros(img.shape[0:2], float)
y_0_x = []
y_0_y = []

y_1_x = []
y_1_y = []

for y in range(0, img.shape[0]-32):
    for x in range(0, img.shape[1]-32):
        if x == 2:
            break
        window = img[y:min(y+32, img.shape[0]), x:min(x+32, img.shape[1]), :]
        for (i, j), element in np.ndenumerate(text_probability_image[y:min(y+32, img.shape[0]), x:min(x+32, img.shape[1])]):
            if y == 0 and x == 0:
                y_0_x.append(x + i)
                y_0_y.append(y + j)
            if y == 1:
                y_1_x.append(x + i)
                y_1_y.append(y + j)

# %%
plt.scatter(y_0_x, y_0_y)
print(max(y_0_x))
print(max(y_0_y))
# Out:
# 31
# 31

# %%
plt.scatter(y_1_x, y_1_y)
print(max(y_1_x))
print(max(y_1_y))
# Out:
# 32
# 32
