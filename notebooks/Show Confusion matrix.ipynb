# %%
import plot_confusion_matrix
import numpy as np
# %matplotlib inline

# %%
with open('../data/confusion_matrix.npy', 'br') as f:
    cm=np.load(f)

# %%
label_set = list(range(10)) + [chr(ord('A')+i) for i in range(26)] + [chr(ord('a')+i) for i in range(26)]

# %%
plot_confusion_matrix.plot_confusion_matrix(cm, label_set, filename='../data/test_images/test_set/confusion_matrix.png')
# Out:
# Normalized confusion matrix
# [[ 0.02173913  0.          0.         ...,  0.          0.          0.        ]
#  [ 0.          0.52173913  0.         ...,  0.          0.          0.        ]
#  [ 0.          0.          0.75510204 ...,  0.          0.          0.        ]
#  ...,
#  [ 0.          0.          0.         ...,  0.25        0.          0.        ]
#  [ 0.          0.          0.         ...,  0.          0.68421053  0.        ]
#  [ 0.          0.          0.         ...,  0.          0.          0.        ]]
