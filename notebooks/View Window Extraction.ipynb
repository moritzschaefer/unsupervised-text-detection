# %% [markdown]
# # Window Extraction
#
# Visualization of text / non-text window extraction

# %%
import sys

sys.path.insert(0, '../src/')

import time
import os
import glob
import numpy as np
import pickle
import xml.etree.ElementTree
import cv2

import preprocessing
import extraction
import config
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-3294b3ba276a> in <module>()
#      12
#      13 import preprocessing
# ---> 14 import extraction
#      15 import config
#      16 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'extraction'

# %%
e = xml.etree.ElementTree.parse(config.XML_PATH).getroot()
dic = extraction.parse_xml(e)
path = '../data/SceneTrialTrain/lfsosa_12.08.2002/IMG_2474.JPG'

img = cv2.imread(path)

plt.imshow(img)
plt.show()

# %%
extraction.extract_random_windows(path, 32, (32, 32), 10, dic, True, True)

# %%
extraction.extract_random_windows(path, 32, (32, 32), 10, dic, False, True)
